# %%
import utils
input_shape = (208, 176, 3)
# Out:
# 2025-03-07 10:12:03.680206: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-03-07 10:12:04.437409: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1741338724.730001   14900 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1741338724.829994   14900 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
import tensorflow as tf

# List all physical devices
gpus = tf.config.list_physical_devices('GPU')
print(gpus)

# Get more details about each GPU
for gpu in gpus:
    details = tf.config.experimental.get_device_details(gpu)
    print(details)
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
# {'compute_capability': (8, 6), 'device_name': 'NVIDIA GeForce RTX 2050'}

# %%
class_names, train_ds, val_ds, test_ds, class_weights  = utils.load_data()
# Out:
# Found 5121 files belonging to 4 classes.
# I0000 00:00:1741338762.079851   14900 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 1768 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 2050, pci bus id: 0000:01:00.0, compute capability: 8.6
# Found 1279 files belonging to 4 classes.
# 2025-03-07 10:12:58.682715: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:450] ShuffleDatasetV3:17: Filling up shuffle buffer (this may take a while): 149 of 10000
# 2025-03-07 10:13:10.874461: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:480] Shuffle buffer filled.
# 2025-03-07 10:13:10.912596: I tensorflow/core/framework/local_rendezvous.cc:405] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2025-03-07 10:13:10.956803: I tensorflow/core/framework/local_rendezvous.cc:405] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# Total number of instances in the dataset: 1296
# ...

# %%
model_name = 'InceptionV3'
base_model = utils.load_model(model_name, input_shape)

model_InceptionV3 = utils.add_custom_layers(base_model)
trained_model_InceptionV3, history_InceptionV3 = utils.compile_and_train(model_InceptionV3, train_ds, test_ds, class_weights, epochs=10)
test_loss, test_acc = model_InceptionV3.evaluate(train_ds)

utils.evaluateModel(model = model_InceptionV3, val_ds = val_ds, history = history_InceptionV3, class_names = class_names)
# Out:
# Epoch 1/10
# /home/tom/miniconda3/envs/DementiAttention/lib/python3.12/site-packages/keras/src/backend/tensorflow/nn.py:708: UserWarning: "`sparse_categorical_crossentropy` received `from_logits=True`, but the `output` argument was produced by a Softmax activation and thus does not represent logits. Was this intended?
#   output, from_logits = _get_logits(
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1741338802.252892   15092 service.cc:148] XLA service 0x7f7748003d40 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1741338802.252982   15092 service.cc:156]   StreamExecutor device (0): NVIDIA GeForce RTX 2050, Compute Capability 8.6
# 2025-03-07 10:13:22.438748: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:268] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# ...

# %%
# Get one batch from test_ds
sample_images, sample_labels = next(iter(test_ds))

# Select one image and its label
img = sample_images[0]  # First image in batch
true_label = sample_labels[0].numpy()  # Convert label to NumPy

# Expand dimensions (Grad-CAM expects a batch dimension)
img_array = tf.expand_dims(img, axis=0)

# Display the selected image
import matplotlib.pyplot as plt
plt.imshow(img.numpy())
plt.title(f"True Label: {true_label}")
plt.axis("off")
plt.show()

# %%
from tensorflow.keras.applications.inception_v3 import preprocess_input
import tensorflow as tf

# Get one batch from test_ds
sample_images, sample_labels = next(iter(test_ds))

# Select one image and its label
img = sample_images[7]  # First image in batch
true_label = sample_labels[7].numpy()  # Convert label to NumPy

# Expand dimensions (Grad-CAM expects a batch dimension)
img_array = tf.expand_dims(img, axis=0)

# Apply InceptionV3 preprocessing
img_array = preprocess_input(img_array)  # Normalize for InceptionV3

# Display the selected image
import matplotlib.pyplot as plt
plt.imshow(img.numpy())  # No need to preprocess for displaying
plt.title(f"True Label: {true_label}")
plt.axis("off")
plt.show()

# %%
import tensorflow as tf
import numpy as np
import cv2
import matplotlib.pyplot as plt
from tensorflow.keras import models
from tensorflow.keras.applications.inception_v3 import preprocess_input

# 🔹 Load the first batch from test_ds
sample_images, sample_labels = next(iter(test_ds))  # Get a batch of images
batch_size = sample_images.shape[0]  # Get number of images in batch

# 🔹 Extract the trained model
model = trained_model_InceptionV3
model.summary()  # Check model structure

# 🔹 Choose an earlier layer for finer spatial details
last_conv_layer_name = "mixed8"  # More granularity than "mixed10"


# 🔹 Create and display Grad-CAM for all images in the first batch
fig, axes = plt.subplots(2, batch_size // 2, figsize=(15, 6))

for i in range(batch_size):
    img = sample_images[i]  # Select each image
    img_array = tf.expand_dims(img, axis=0)  # Add batch dimension
    img_array = preprocess_input(img_array)  # Preprocess for InceptionV3

    # Generate Grad-CAM heatmap
    heatmap = utils.get_grad_cam(model, img_array, last_conv_layer_name)

    # Superimpose heatmap onto image
    superimposed_img = utils.superimpose_heatmap(img, heatmap)

    # 🔹 Display the results
    ax = axes[i // (batch_size // 2), i % (batch_size // 2)]
    ax.imshow(superimposed_img)
    ax.set_title(f"Image {i + 1}")
    ax.axis("off")

plt.tight_layout()
plt.show()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ inception_v3 (Functional)       │ (None, 5, 4, 2048)     │    21,802,784 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 40960)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 256)            │    10,486,016 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 64)             │        16,448 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 4)              │           260 │
# ...

# %% [markdown]
# # Evaluate the model
# loss, acc = model.evaluate(test_images, test_labels, verbose=2)
# print("Untrained model, accuracy: {:5.2f}%".format(100 * acc))
